# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
names = lambda o: print([name for name in dir(o) if name[0] != "_"])

# %%
plt.plot([3, 5, 1, 2]);

# %%
tips = sns.load_dataset("tips")

# %%
d = [
    tips.tip.loc[tips.day == "Thur"],
    tips.tip.loc[tips.day == "Fri"],
    tips.tip.loc[tips.day == "Sat"],
    tips.tip.loc[tips.day == "Sun"],
]

# %%
plt.boxplot(d);

# %%
sns.set()

# %%
sns.boxplot(data = tips, x = "day", y = "tip");

# %%
plt.violinplot(d);

# %%
sns.violinplot(data = tips, x = "day", y = "tip");

# %%
plt.plot([2, 5, 1, 4]);

# %%
plt.figure()

# %%
plt.figure()

# %%
type(plt.figure())
# Out:
# matplotlib.figure.Figure

# %%
fig = plt.figure()

# %%
fig_ = plt.figure(figsize = (10, 5))

# %%
plt.plot([2, 3, 4]);

# %%
fig_ = plt.figure(figsize = (10, 5))
plt.plot([2, 3, 4]);

# %%
plt.figure(figsize = (10, 5))
plt.plot([2, 3, 4])
plt.axes([0.5, 0.5, 1, 1])
plt.pie([2, 4, 1]);

# %%
fig = plt.figure(figsize = (10, 5))
ax1 = plt.axes([0, 0 ,1, 1])
ax1.plot([2, 3, 4])
ax2 = plt.axes([0.5, 0.5, 1, 1])
ax2.pie([2, 4, 1]);

# %%
plt.subplots()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots()

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
fig, ax = plt.subplots(2, 3)

# %%
ax
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
ax[1, 1]
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(2, 3)

# %%
names(ax)
# Out:
# ['T', 'all', 'any', 'argmax', 'argmin', 'argpartition', 'argsort', 'astype', 'base', 'byteswap', 'choose', 'clip', 'compress', 'conj', 'conjugate', 'copy', 'ctypes', 'cumprod', 'cumsum', 'data', 'diagonal', 'dot', 'dtype', 'dump', 'dumps', 'fill', 'flags', 'flat', 'flatten', 'getfield', 'imag', 'item', 'itemset', 'itemsize', 'max', 'mean', 'min', 'nbytes', 'ndim', 'newbyteorder', 'nonzero', 'partition', 'prod', 'ptp', 'put', 'ravel', 'real', 'repeat', 'reshape', 'resize', 'round', 'searchsorted', 'setfield', 'setflags', 'shape', 'size', 'sort', 'squeeze', 'std', 'strides', 'sum', 'swapaxes', 'take', 'tobytes', 'tofile', 'tolist', 'tostring', 'trace', 'transpose', 'var', 'view']

# %%
fig, ax = plt.subplots(2, 3, figsize = (15, 5))
ax[1, 1].plot([2, 4, 2, 6])
ax[0, 2].pie([4, 1, 3]);

# %%
fig.axes
# Out:
# [<AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>]

# %%
fig, ax = plt.subplots(2, 3, figsize = (15, 5))
ax[1, 1].plot([2, 4, 2, 6])
ax[0, 2].pie([4, 1, 3]);
