# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
names = lambda o: print([name for name in dir(o) if name[0] != "_"])

# %%
url = "https://geoportalgasolineras.es/resources/files/preciosEESS_es.xls"

# %%
data = pd.read_excel(url)

# %%
data.head()
# Out:
#          Fecha:                                   24/11/2021 17:00 Unnamed: 2  \
# 0  Descripción:  Archivo de todos los productos en todas las es...        NaN
# 1       Siglas:  Margen - D: Derecho, I: Izquierdo, N: No aplic...        NaN
# 2     Provincia                                          Municipio  Localidad
# 3      ALBACETE                                          ABENGIBRE  ABENGIBRE
# 4      ALBACETE                                           ALBACETE   ALBACETE
#
#       Unnamed: 3                      Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0            NaN                             NaN        NaN        NaN
# 1            NaN                             NaN        NaN        NaN
# 2  Código postal                       Dirección     Margen   Longitud
# 3          02250  AVENIDA CASTILLA LA MANCHA, 26          D  -1,539167
# 4          02001  CALLE FEDERICO GARCIA LORCA, 5          I  -1,846361
#
# ...

# %%
data.isna()
# Out:
#        Fecha:  18/11/2021 21:00  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0       False             False        True        True        True
# 1       False             False        True        True        True
# 2       False             False       False       False       False
# 3       False             False       False       False       False
# 4       False             False       False       False       False
# ...       ...               ...         ...         ...         ...
# 11294   False             False       False       False       False
# 11295   False             False       False       False       False
# 11296   False             False       False       False       False
# 11297   False             False       False       False       False
# 11298   False             False       False       False       False
#
#        Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0            True        True        True        True        True  ...
# ...

# %%
data.iloc[:, 7].isnull()
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 11294    False
# 11295    False
# 11296    False
# 11297    False
# 11298    False
# Name: Unnamed: 7, Length: 11299, dtype: bool

# %%
data.loc[data.iloc[:, 2] == "ALBACETE"]
# Out:
#       Fecha: 18/11/2021 21:00 Unnamed: 2 Unnamed: 3  \
# 4   ALBACETE         ALBACETE   ALBACETE      02001
# 5   ALBACETE         ALBACETE   ALBACETE      02001
# 6   ALBACETE         ALBACETE   ALBACETE      02001
# 7   ALBACETE         ALBACETE   ALBACETE      02001
# 8   ALBACETE         ALBACETE   ALBACETE      02005
# 9   ALBACETE         ALBACETE   ALBACETE      02005
# 10  ALBACETE         ALBACETE   ALBACETE      02005
# 11  ALBACETE         ALBACETE   ALBACETE      02002
# 12  ALBACETE         ALBACETE   ALBACETE      02006
# 13  ALBACETE         ALBACETE   ALBACETE      02006
# 14  ALBACETE         ALBACETE   ALBACETE      02006
# 15  ALBACETE         ALBACETE   ALBACETE      02006
# 16  ALBACETE         ALBACETE   ALBACETE      02006
# 17  ALBACETE         ALBACETE   ALBACETE      02006
# 18  ALBACETE         ALBACETE   ALBACETE      02006
# 19  ALBACETE         ALBACETE   ALBACETE      02006
# 20  ALBACETE         ALBACETE   ALBACETE      02006
# ...

# %%
data.loc[data.iloc[:, 7].isnull()].index
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
data.drop(data.loc[data.iloc[:, 7].isnull()].index)
# Out:
#           Fecha: 18/11/2021 21:00       Unnamed: 2     Unnamed: 3  \
# 2      Provincia        Municipio        Localidad  Código postal
# 3       ALBACETE        ABENGIBRE        ABENGIBRE          02250
# 4       ALBACETE         ALBACETE         ALBACETE          02001
# 5       ALBACETE         ALBACETE         ALBACETE          02001
# 6       ALBACETE         ALBACETE         ALBACETE          02001
# ...          ...              ...              ...            ...
# 11294   ZARAGOZA         ZARAGOZA         ZARAGOZA          50197
# 11295   ZARAGOZA         ZARAGOZA         ZARAGOZA          50197
# 11296   ZARAGOZA            ZUERA            ZUERA          50800
# 11297   ZARAGOZA            ZUERA            ZUERA          50800
# 11298   ZARAGOZA            ZUERA  ONTINAR DE SALZ          50810
#
#                                Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 2                               Dirección     Margen   Longitud    Latitud
# ...
