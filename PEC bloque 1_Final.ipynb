# %% [markdown]
# <a name = "inicio"></a>
# ![image.png](attachment:image.png)
# <p style="text-align:center;font-size:35px;font-weight: bold;">PRUEBA DE EVALUACIÓN CONTINUA</p>
# <p style="text-align:center;font-size:35px;font-weight: bold;">Bloque 1</p>

# %% [markdown]
# # Objetivos
#
# El objetivo de esta PEC es evaluar el conocimiento del alumno en el uso básico de las librerías de Python **NumPy** y **pandas**, aplicándolas en la visualización y transformación de conjuntos de datos.
#
# La prueba consta de tres bloques de preguntas correspondientes a tres niveles de dificultad:
#
# * **Nivel básico**, en las que el alumno deberá ser capaz de realizar tareas, ejercicios o prácticas similares a las aprendidas en la documentación del módulo.
# * **Nivel intermedio**, en las que el alumno deberá ser capaz de aplicar las técnicas, conocimientos y habilidades revisadas en la documentación a problemas con elementos diferentes.
# * **Nivel avanzado**, en las que el alumno deberá ser capaz de amplicar las técnicas, conocimientos y habilidades aprendidas investigando nuevos aspectos, problemas o elementos.

# %% [markdown]
# # Importante
#
# * El alumno deberá completar este cuaderno sin modificar las preguntas ni modificar la estructura del propio cuaderno (se pueden añadir celdas, pero no modificar ni eliminar las existentes)
# * El entregable será el cuaderno Jupyter (no PDF's ni material en ningún otro soporte)
# * El cuaderno Jupyter con las respuestas deberá poder ser reejecutado sin que se produzca ningún error
# * Salvo que se pida lo contrario, no se cargará ningún fichero desde el equipo local
# * Salvo que se especifique otra cosa, deberán utilizarse siempre las herramientas proveídas por las librerías NumPy, Pandas, Seaborn o Matplotlib. No puede recurrirse a otras librerías.
#
# El incumplimiento de cualquiera de estas normal supondrá la invalidación del ejercicio

# %% [markdown]
# * [NIVEL BÁSICO: 5 puntos](#NIVEL-BÁSICO:-5-puntos)
# * [NIVEL INTERMEDIO: 3 puntos](#NIVEL-INTERMEDIO:-3-puntos)
# * [NIVEL AVANZADO: 2 puntos](#NIVEL-AVANZADO:-2-puntos)

# %% [markdown]
# # NIVEL BÁSICO: 5 puntos
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
#     <strong>Pregunta 1: 0.5 puntos</strong>
#
# Fija la semilla del generador de números aleatorios de NumPy con el valor 18 y genera un array unidimensional de 10 valores extraídos de una distribución gaussiana de media 10 y desviación estándar 2. Almacénalo en la variable "a" y muéstrala en pantalla.
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 2: 0.75 puntos</strong>
#
# Crea un array de 10 filas y 2 columnas con números aleatorios enteros entre 0 y 10 ambos incluidos. Almacénalo en la variable "b". Concatena las variables a y b de forma que el resultado sea un array de 10 filas y 3 columnas. Almacena el resultado en la variable "c" y muéstrala en pantalla.
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 3: 0.75 puntos</strong>
#
# Usando la función np.where, sustituye todos los valores de c menores que 10 por ceros y asigna el resultado a la variable "d".
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 4: 0.75 puntos</strong>
#
# Usando una función universal, eleva cada elemento del array d al cuadrado
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 5: 0.75 puntos</strong>
#
# Carga en la variable "tips" el dataset "tips" proveído por la librería seaborn y extrae los valores de la quinta, tercera y segunda filas (es decir, las filas con índice 4, 2 y 1) en este orden, y columnas "sex", "size" y "tip" también en este orden y asígnalas a la variable "sample" asegurándote de que se está realizando una copia independiente. El resultado deberá ser un dataframe de tamaño (3, 3). Muéstralo en pantalla.
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 6: 0.75 puntos</strong>
#
# Actualiza "tips" usando el método where de forma que todos los valores del campo "tip" que sean menores que 2 se sustituyan por un NaN. Calcula el número de NaN's de la columna tip del dataset resultante.
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 7: 0.75 puntos</strong>
#
# Vuelve a cargar el dataset tips proveído por Seaborn en la variable "tips". Reemplaza el nombre de la columna "total_bill" por "total" usando el método *rename*. A continuación, lleva la columna "total" al índice y muestra el resultado en pantalla.
# </div>

# %% [markdown]
# # NIVEL INTERMEDIO: 3 puntos
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 8: 0.75 puntos</strong>
#
# Carga en la variable "titanic" el dataset homónimo proveído por la librería seaborn. Usando el método *reindex*, quédate con los campos "survived", "class", "sex", "age", "fare" y "embark_town".
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 9: 0.75 puntos</strong>
#
# Utilizando el método groupby, calcula la edad media de los pasajeros según el puerto de embarque.
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 10: 0.75 puntos</strong>
#
# ¿Cuántas mujeres hay en el dataset mayores de 38 años que hayan pagado más de 30 y menos de 40 libras?
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 11: 0.75 puntos</strong>
#
# Vuelve a cargar el dataset tips proveído por Seaborn en la variable "tips". Añade a la tabla "tips" una nueva columna conteniendo la suma la factura y de la propina por comensal y muestra los primeros registros del dataframe tras ordenarlo de mayor a menor según este nuevo campo.
# </div>

# %% [markdown]
# # NIVEL AVANZADO: 2 puntos
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# Abre en tu navegador la página web indicada en la siguiente celda y, usando pandas, lee (sin descargar a tu ordenador) los datos correspondientes a los viajes en bicicleta realizados en 2010 y 2011 (tendrás que copiar los enlaces a ambos datasets y pegarlos en tu notebook). Cárgalos asegurándote de que los campos "Start date" y "End date" son leídos como fechas y no como textos y une ambos dataframes en uno solo (verticalmente). Llámalo "trips".
# </div>

# %% [markdown]
# https://s3.amazonaws.com/capitalbikeshare-data/index.html

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# ¿Cuántos registros hay en total?
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
#     <strong>Pregunta 12: 0.5 puntos</strong>
#
# ¿Cuántos viajes ha realizados la bicicleta cuyo número es "W00970" que hayan comenzado en la estación 31600 y que hayan terminado en la misma estación?
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 13: 0.5 puntos</strong>
#
# ¿Cuántos viajes de la tabla "trips" tienen una duración superior al valor correspondiente a 3 veces la mediana de dicho campo?
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
#     <strong>Pregunta 14: 0.5 puntos</strong>
#     <p>Usando el método <strong>drop</strong> de un dataframe, elimina todos los registros cuya duración sea superior al valor correspondiente a 3 veces la mediana de dicho campo.</p>
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# ¿Cuántos registros tenemos después de la eliminación?
# </div>

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
#     <strong>Pregunta 15: 0.50 puntos</strong>
#     <p>Explica el problema encontrado y cómo lo has solucionado.</p>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
names = lambda o: print([name for name in dir(o) if not name.startswith("_")])

# %%
# help(np.random.normal)

# %%
def info(x):
    print()
    print("Funcción 'ndim'   :",x.ndim)
    print("Funcción 'shape'  :", x.shape)
    print("Funcción 'dtype'  :", x.dtype)
    print()

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
#     <strong>Pregunta 1: 0.5 puntos</strong>
#
# Fija la semilla del generador de números aleatorios de NumPy con el valor 18 y genera un array unidimensional de 10 valores extraídos de una distribución gaussiana de media 10 y desviación estándar 2. Almacénalo en la variable "a" y muéstrala en pantalla.
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
mu, sigma = 10, 2 # media y desvio estandar

np.random.seed(18)
a = np.random.normal(mu, sigma, 10)

print(a)
info(a)
# Out:
# [10.15885689 14.38040471  9.73021571 10.32103596 10.88539569 11.24678288
#  12.01780697 10.78849758  9.32722659  8.70818707]
#
# Funcción 'ndim'   : 1
# Funcción 'shape'  : (10,)
# Funcción 'dtype'  : float64

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 2:</strong>
#
# Crea un array de 10 filas y 2 columnas con números aleatorios enteros entre 0 y 10 ambos incluidos. Almacénalo en la variable "b". Concatena las variables a y b de forma que el resultado sea un array de 10 filas y 3 columnas. Almacena el resultado en la variable "c" y muéstrala en pantalla.
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
b = np.random.randint(0, 11, size = (10, 2))
print("Informaciones del array 'b'")
info(b)
c = np.c_[a, b]
print(c)
info(c)
# Out:
# Informaciones del array 'b'
#
# Funcción 'ndim'   : 2
# Funcción 'shape'  : (10, 2)
# Funcción 'dtype'  : int64
#
# [[10.15885689  6.          5.        ]
#  [14.38040471  8.          2.        ]
#  [ 9.73021571  0.          9.        ]
#  [10.32103596 10.         10.        ]
#  [10.88539569 10.          3.        ]
#  [11.24678288  2.          3.        ]
#  [12.01780697  5.         10.        ]
#  [10.78849758  7.          2.        ]
#  [ 9.32722659  9.          6.        ]
#  [ 8.70818707  9.          3.        ]]
#
# Funcción 'ndim'   : 2
# Funcción 'shape'  : (10, 3)
# Funcción 'dtype'  : float64

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 3: 0.75 puntos</strong>
#
# Usando la función np.where, sustituye todos los valores de c menores que 10 por ceros y asigna el resultado a la variable "d".
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
d = np.where(c < 10, 0, c)
d
# Out:
# array([[10.15885689,  0.        ,  0.        ],
#        [14.38040471,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ],
#        [10.32103596, 10.        , 10.        ],
#        [10.88539569, 10.        ,  0.        ],
#        [11.24678288,  0.        ,  0.        ],
#        [12.01780697,  0.        , 10.        ],
#        [10.78849758,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ]])

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 4: 0.75 puntos</strong>
#
# Usando una función universal, eleva cada elemento del array d al cuadrado
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
np.square(d)
# Out:
# array([[103.20237326,   0.        ,   0.        ],
#        [206.79603976,   0.        ,   0.        ],
#        [  0.        ,   0.        ,   0.        ],
#        [106.52378339, 100.        , 100.        ],
#        [118.49183925, 100.        ,   0.        ],
#        [126.49012519,   0.        ,   0.        ],
#        [144.42768442,   0.        , 100.        ],
#        [116.39168006,   0.        ,   0.        ],
#        [  0.        ,   0.        ,   0.        ],
#        [  0.        ,   0.        ,   0.        ]])

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 5: 0.75 puntos</strong>
#
# Carga en la variable "tips" el dataset "tips" proveído por la librería seaborn y extrae los valores de la quinta, tercera y segunda filas (es decir, las filas con índice 4, 2 y 1) en este orden, y columnas "sex", "size" y "tip" también en este orden y asígnalas a la variable "sample" asegurándote de que se está realizando una copia independiente. El resultado deberá ser un dataframe de tamaño (3, 3). Muéstralo en pantalla.
#
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
tips = sns.load_dataset("tips")
sample = tips[["sex", "size", "tip"]].loc[[4, 2, 1]]
print("ID tips:   ",id(tips))
print("ID sample: ",id(sample))
sample
# Out:
# ID tips:    140468930584928
# ID sample:  140469208884080
#       sex  size   tip
# 4  Female     4  3.61
# 2    Male     3  3.50
# 1    Male     3  1.66

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 6: 0.75 puntos</strong>
#
# Actualiza "tips" usando el método where de forma que todos los valores del campo "tip" que sean menores que 2 se sustituyan por un NaN. Calcula el número de NaN's de la columna tip del dataset resultante.
#
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
# help(tips.where)
t = tips
t["tip"].where(t.tip > 2, inplace=True)
t.tip.head()
# Out:
# 0     NaN
# 1     NaN
# 2    3.50
# 3    3.31
# 4    3.61
# Name: tip, dtype: float64

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 7: 0.75 puntos</strong>
#
# Vuelve a cargar el dataset tips proveído por Seaborn en la variable "tips". Reemplaza el nombre de la columna "total_bill" por "total" usando el método *rename*. A continuación, lleva la columna "total" al índice y muestra el resultado en pantalla.
#
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
tips_ = sns.load_dataset("tips")
#help(tips_.rename)
tips_.rename(columns = {"total_bill": "total"}, inplace = True)
tips_.set_index("total", inplace = True)
tips_
# Out:
#         tip     sex smoker   day    time  size
# total
# 16.99  1.01  Female     No   Sun  Dinner     2
# 10.34  1.66    Male     No   Sun  Dinner     3
# 21.01  3.50    Male     No   Sun  Dinner     3
# 23.68  3.31    Male     No   Sun  Dinner     2
# 24.59  3.61  Female     No   Sun  Dinner     4
# ...     ...     ...    ...   ...     ...   ...
# 29.03  5.92    Male     No   Sat  Dinner     3
# 27.18  2.00  Female    Yes   Sat  Dinner     2
# 22.67  2.00    Male    Yes   Sat  Dinner     2
# 17.82  1.75    Male     No   Sat  Dinner     2
# 18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 8: 0.75 puntos</strong>
#
# Carga en la variable "titanic" el dataset homónimo proveído por la librería seaborn. Usando el método *reindex*, quédate con los campos "survived", "class", "sex", "age", "fare" y "embark_town".
#
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
#     </div>

# %%
titanic = pd.DataFrame(
    data = sns.load_dataset("titanic").copy(),
    columns = ["survived", "class", "sex", "age", "fare", "embark_town"])
titanic
# help(titanic.reindex)
# Out:
#      survived   class     sex   age     fare  embark_town
# 0           0   Third    male  22.0   7.2500  Southampton
# 1           1   First  female  38.0  71.2833    Cherbourg
# 2           1   Third  female  26.0   7.9250  Southampton
# 3           1   First  female  35.0  53.1000  Southampton
# 4           0   Third    male  35.0   8.0500  Southampton
# ..        ...     ...     ...   ...      ...          ...
# 886         0  Second    male  27.0  13.0000  Southampton
# 887         1   First  female  19.0  30.0000  Southampton
# 888         0   Third  female   NaN  23.4500  Southampton
# 889         1   First    male  26.0  30.0000    Cherbourg
# 890         0   Third    male  32.0   7.7500   Queenstown
#
# [891 rows x 6 columns]

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 9: 0.75 puntos</strong>
#
# Utilizando el método groupby, calcula la edad media de los pasajeros según el puerto de embarque.
#
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
titanic.groupby(by = "embark_town").mean().age
# Out:
# embark_town
# Cherbourg      30.814769
# Queenstown     28.089286
# Southampton    29.445397
# Name: age, dtype: float64

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 10: 0.75 puntos</strong>
#
# ¿Cuántas mujeres hay en el dataset mayores de 38 años que hayan pagado más de 30 y menos de 40 libras?
#
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
tm = titanic.loc[titanic.sex == "female"].loc[titanic.age > 38].loc[titanic.fare > 30].loc[titanic.fare < 40]
tm.shape[0]
# Out:
# 5

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 11: 0.75 puntos</strong>
#
# Vuelve a cargar el dataset tips proveído por Seaborn en la variable "tips". Añade a la tabla "tips" una nueva columna conteniendo la suma la factura y de la propina por comensal y muestra los primeros registros del dataframe tras ordenarlo de mayor a menor según este nuevo campo.
#
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
#     </div>

# %%
tips_11 = sns.load_dataset("tips")
tips_11[["Suma"]] = tips_11.total_bill + tips_11.tip
tips_11.sort_values("Suma", ascending = False)
# Out:
#      total_bill    tip     sex smoker   day    time  size   Suma
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  60.81
# 212       48.33   9.00    Male     No   Sat  Dinner     4  57.33
# 59        48.27   6.73    Male     No   Sat  Dinner     4  55.00
# 156       48.17   5.00    Male     No   Sun  Dinner     6  53.17
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3  48.85
# ..          ...    ...     ...    ...   ...     ...   ...    ...
# 218        7.74   1.44    Male    Yes   Sat  Dinner     2   9.18
# 195        7.56   1.44    Male     No  Thur   Lunch     2   9.00
# 111        7.25   1.00  Female     No   Sat  Dinner     1   8.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2   6.75
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1   4.07
#
# [244 rows x 8 columns]

# %% [markdown]
# # NIVEL AVANZADO: 2 puntos

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# Abre en tu navegador la página web indicada en la siguiente celda y, usando pandas, lee (sin descargar a tu ordenador) los datos correspondientes a los viajes en bicicleta realizados en 2010 y 2011 (tendrás que copiar los enlaces a ambos datasets y pegarlos en tu notebook). Cárgalos asegurándote de que los campos "Start date" y "End date" son leídos como fechas y no como textos y une ambos dataframes en uno solo (verticalmente). Llámalo "trips".
#
#
# ¿Cuántos registros hay en total?
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
# help(pd.read_csv)
url_2010 = "https://s3.amazonaws.com/capitalbikeshare-data/2010-capitalbikeshare-tripdata.zip"
data_2010 = pd.read_csv(url_2010, compression = "zip", parse_dates = True, date_parser = "dateutil.parser.parser")
url_2011 = "https://s3.amazonaws.com/capitalbikeshare-data/2011-capitalbikeshare-tripdata.zip"
data_2011 = pd.read_csv(url_2011, compression = "zip", parse_dates = True, date_parser = "dateutil.parser.parser")
trips = data_2010.append(data_2011, ignore_index = True)
print(data_2010.shape[0], data_2011.shape[0])
print("Él total de registros és: ",trips.shape[0])
# Out:
# 115597 1226767
# Él total de registros és:  1342364

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
#     <strong>Pregunta 12: 0.5 puntos</strong>
#
# ¿Cuántos viajes ha realizados la bicicleta cuyo número es "W00970" que hayan comenzado en la estación 31600 y que hayan terminado en la misma estación?
#
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
#     </div>

# %%
x = trips.loc[trips["Bike number"] == "W00970"].loc[trips["Start station number"] == trips["End station number"]]
x.shape[0]
# Out:
# 52

# %%
trips[(trips["Bike number"] == "W00970") & (trips["Start station number"] == 31600) & (trips["End station number"] == 31600)]
# Out:
#         Duration           Start date             End date  \
# 717184      2423  2011-07-18 15:59:56  2011-07-18 16:40:19
# 946754      2000  2011-09-11 13:35:10  2011-09-11 14:08:31
#
#         Start station number  Start station  End station number  \
# 717184                 31600  5th & K St NW               31600
# 946754                 31600  5th & K St NW               31600
#
#           End station Bike number Member type
# 717184  5th & K St NW      W00970      Casual
# 946754  5th & K St NW      W00970      Casual

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
# <strong>Pregunta 13: 0.5 puntos</strong>
#
# ¿Cuántos viajes de la tabla "trips" tienen una duración superior al valor correspondiente a 3 veces la mediana de dicho campo?
#
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
#     </div>

# %%
trips_d = trips.loc[trips["Duration"] > (3 * trips["Duration"].median())]
print(trips_d.shape[0])
trips_d
# Out:
# 123540
#          Duration           Start date             End date  \
# 2            2690  2010-09-20 12:05:37  2010-09-20 12:50:27
# 8            2496  2010-09-20 12:18:38  2010-09-20 13:00:15
# 17           2988  2010-09-20 12:41:37  2010-09-20 13:31:25
# 32           3044  2010-09-20 14:28:39  2010-09-20 15:19:23
# 40           2228  2010-09-20 15:27:54  2010-09-20 16:05:03
# ...           ...                  ...                  ...
# 1342268      2078  2011-12-31 21:33:08  2011-12-31 22:07:46
# 1342276      2205  2011-12-31 21:43:12  2011-12-31 22:19:58
# 1342277      2157  2011-12-31 21:44:01  2011-12-31 22:19:58
# 1342317      2447  2011-12-31 22:29:23  2011-12-31 23:10:10
# 1342362      2060  2011-12-31 23:55:12  2012-01-01 00:29:33
#
#          Start station number                              Start station  \
# 2                       31600                              5th & K St NW
# 8                       31600                              5th & K St NW
# ...

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
#     <strong>Pregunta 14: 0.5 puntos</strong>
#     <p>Usando el método <strong>drop</strong> de un dataframe, elimina todos los registros cuya duración sea superior al valor correspondiente a 3 veces la mediana de dicho campo.</p>
#
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
#     </div>

# %%
#help(trips.drop)
#trips.drop(trips["Duration"] > (3 * trips["Duration"].median()))
'''
No he sido capaz de poner la condición junto con "drop"
'''
trips.reset_index(inplace = True)
trips_reduced = trips.drop(trips[trips.Duration > (trips.Duration.median() * 3)].index)
trips_reduced
# Out:
#            index  Duration           Start date             End date  \
# 0              0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56
# 1              1        61  2010-09-20 11:41:22  2010-09-20 11:42:23
# 3              3      1406  2010-09-20 12:06:05  2010-09-20 12:29:32
# 4              4      1413  2010-09-20 12:10:43  2010-09-20 12:34:17
# 5              5       982  2010-09-20 12:14:27  2010-09-20 12:30:50
# ...          ...       ...                  ...                  ...
# 1342358  1342358       349  2011-12-31 23:40:51  2011-12-31 23:46:40
# 1342359  1342359       300  2011-12-31 23:41:19  2011-12-31 23:46:20
# 1342360  1342360       387  2011-12-31 23:46:43  2011-12-31 23:53:10
# 1342361  1342361       261  2011-12-31 23:47:27  2011-12-31 23:51:49
# 1342363  1342363       468  2011-12-31 23:55:56  2012-01-01 00:03:45
#
#          Start station number                      Start station  \
# 0                       31208           M St & New Jersey Ave SE
# ...

# %% [markdown]
# <div style="background:##ccebf5;padding:20px;color:#000000">
#     <strong>Pregunta 15: 0.50 puntos</strong>
#     <p>Explica el problema encontrado y cómo lo has solucionado.</p>
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
# </div>

# %%
trips_ = trips.loc[trips["Duration"] > (3 * trips["Duration"].median())]
trips_
# Out:
#            index  Duration           Start date             End date  \
# 2              2      2690  2010-09-20 12:05:37  2010-09-20 12:50:27
# 8              8      2496  2010-09-20 12:18:38  2010-09-20 13:00:15
# 17            17      2988  2010-09-20 12:41:37  2010-09-20 13:31:25
# 32            32      3044  2010-09-20 14:28:39  2010-09-20 15:19:23
# 40            40      2228  2010-09-20 15:27:54  2010-09-20 16:05:03
# ...          ...       ...                  ...                  ...
# 1342268  1342268      2078  2011-12-31 21:33:08  2011-12-31 22:07:46
# 1342276  1342276      2205  2011-12-31 21:43:12  2011-12-31 22:19:58
# 1342277  1342277      2157  2011-12-31 21:44:01  2011-12-31 22:19:58
# 1342317  1342317      2447  2011-12-31 22:29:23  2011-12-31 23:10:10
# 1342362  1342362      2060  2011-12-31 23:55:12  2012-01-01 00:29:33
#
#          Start station number                              Start station  \
# ...

# %% [markdown]
# Hola Rodrigo,
#
# Podrías haber insertado celdas detrás de cada pregunta... :)
#
# Paso a corregir tu ejercicio:
#
# * Ejercicio 6: Has cometido un pequeño error. Se pide sustituir todos los valores de "tip" que sean menores que 2. Tú has sustituido todos los menores o igual a 2.
#
# * Ejercicio 12: No está bien resuelto, Estas calculando el número de viajes en los que la estación de comienzo es igual a la de finalización, pero se pide que ésta estación sea la 31600 (dato que no consideras). Te pongo la mitad de la nota en todo caso, pues estás usando correctamente el método .loc. En todo caso hubiera sido más eficiente hacer todo en una única selección, no en dos:
#
# trips[(trips['Bike number'] == "W00970") & (trips['Start station number'] == 31600) & (trips['End station number'] == 31600)]
#
# Y no has contestado las preguntas 14 y 15. La 14 se realizaba correctamente así:
#
# trips.reset_index(inplace = True)
# trips_reduced = trips.drop(trips[trips.Duration > (trips.Duration.median() * 3)].index)
#
# Y fíjate que estoy reseteando el índice para no eliminar registros de las dos tablas iniciales que puedan tener el mismo índice...
#
# Saludos!
